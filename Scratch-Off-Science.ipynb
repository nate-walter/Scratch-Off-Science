# %% [markdown]
# # I'm not much of a gambler, but for Data Science I guess I'll give it a shot

# %% [markdown]
# ## I dedicated three hundred dollars to invest in Illinois Lottery Scratch Off Tickets.<br>I decided to play the more expensive, higher-payout, scratch off cards that cost thirty dolars a piece. I first went to [The Lottery Website](https://www.illinoislottery.com/about-the-games/unpaid-instant-games-prizes) to see which cards had unpaid large prizes and decided on a scratch card based on these figures.

# %% [markdown]
# # Round 1

# %%
attempt_1 = "Round 1"

start_with_1 = 300

spent_1 = 300

left_with_1 = 0

won_1 = 30 + 40 + 30 + 50 + 50

status_1 = won_1 - spent_1

reinvest_1 = start_with_1 - abs(status_1)

# %%
print(f"Starting with ${start_with_1}")
print()
print(f"Spent ${spent_1} ")
print()
print(f"Left with ${left_with_1}")
print()
print(f"Won ${won_1}")
print()
print(f"Result ${status_1}")
print()
print(f"Result to reinvest ${reinvest_1}")
# Out:
# Starting with $300
#
# Spent $300
#
# Left with $0
#
# Won $200
#
# Result $-100
#
# Result to reinvest $200

# %% [markdown]
# # Round 2
# ## There was an issue with the lottery card dispensor, so I only got sixty dollars worth (two cards)

# %%
attempt_2 = "Round 2"

start_with_2 = reinvest_1

spent_2 = 60

left_with_2 = start_with_2 - spent_2

won_2 = 50 + 10 + 20 + 20 + 30 + 20

status_2 = won_2 - spent_2

ended_with_2 = won_2 + left_with_2

#reinvest_1 = start_with_1 - abs(status_1)

# %%
print(f"Starting with ${start_with_2}")
print()
print(f"Spent ${spent_2} ")
print()
print(f"Left with ${start_with_2 - spent_2}")
print()
print(f"Won ${won_2}")
print()
print(f"Result to reinvest ${ended_with_2}")
# Out:
# Starting with $200
#
# Spent $60
#
# Left with $140
#
# Won $150
#
# Result to reinvest $290

# %% [markdown]
# # Round 3

# %%
attempt_3 = "Round 3"

start_with_3 = ended_with_2

spent_3 = start_with_3

left_with_3 = start_with_3 - spent_3

won_3 = 50 + 50 + 40 + 40

status_3 = won_3 - spent_3

lost_3 = spent_3 - won_3

ended_with_3 = won_3 + left_with_3

# %%
print(f"Starting with ${start_with_3}")
print()
print(f"Spent ${spent_3} ")
print()
print(f"Left with ${start_with_3 - spent_3}")
print()
print(f"Won ${won_3}")
print()
print(f"Lost ${lost_3}")
print()
print(f"Result to reinvest ${ended_with_3}")
# Out:
# Starting with $290
#
# Spent $290
#
# Left with $0
#
# Won $180
#
# Lost $110
#
# Result to reinvest $180

# %% [markdown]
# # Round 4

# %%
attempt_4 = "Round 4"

start_with_4 = ended_with_3

spent_4 = start_with_4

left_with_4 = start_with_4 - spent_4

won_4 = 100 + 40 + 30

status_4 = won_4 - spent_4

lost_4 = spent_4 - won_4

ended_with_4 = won_4 + left_with_4

# %%
print(f"Starting with ${start_with_4}")
print()
print(f"Spent ${spent_4} ")
print()
print(f"Left with ${start_with_4 - spent_4}")
print()
print(f"Won ${won_4}")
print()
print(f"Lost ${lost_4}")
print()
print(f"Result to reinvest ${ended_with_4}")
# Out:
# Starting with $180
#
# Spent $180
#
# Left with $0
#
# Won $170
#
# Lost $10
#
# Result to reinvest $170

# %% [markdown]
# # Overall Status at the moment

# %%
attempt_4 = "Round 4"

print(f"""We're sitting at ${ended_with_4}
We started with ${start_with_1}
So far we're at ${won_4 - spent_1} in the
Scratch Off Experiment
after {attempt_4}
""")
# Out:
# We're sitting at $170
# We started with $300
# So far we're at $-130 in the
# Scratch Off Experiment
# after Round 4

# %% [markdown]
# # I chose the first four rounds of cards by scanning through the available prizes manually and chosing what looked to be the best scratch off tickets. Now we'll get a little more nerdy about it and enter the info from [The Lottery Website](https://www.illinoislottery.com/about-the-games/unpaid-instant-games-prizes) into a Pandas DataFrame. This should allow us to work with the figures with more effectiveness.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
prize_values  = [20, 25, 30, 40, 50, 70, 75, 100, 150, 200, 250, 300, 350, 400, 500, 1000, 3000, 5000, 
                         7000, 10000, 17777, 20000, 25000, 50000, 77777, 100000, 600000, 1000000, 
                         1200000, 1777777, 3000000, 7200000]

# %%
data = {"card_name" : ["DIAMOND CROSSWORD 10X", "1,000,000 CASH CELEBRATION!", "MILLION $ MATCH", "$5 MILLION RICHES",
                      "PLATINUM DIAMOND SPECTACULAR", "ULTIMATE MILLIONS", "$1,000,000 MERRY MULTIPLIER", "MILLION DOLLAR MEGA MULTIPLIER",
                      "$2,000,000 EXTREME CASH", "$2,000,000 BANKROLL", "WIN BIG", "100X THE CASH", "$2,000,000 JACKPOT",
                      "20 YEARS OF CASH", "PAY ME!", "LUCKY 7 DELUXE"],
       "card_price" : [25, 30, 30, 30, 30, 30, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20],
       "weeks_in_market" : [86, 12, 34, 52, 73, 158, 8, 21, 30, 39, 43, 48, 69, 92, 121, 142],
        "$20_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 140798, 253307, 445404, 110747, 258604, 251403, 328687, 839945, 160159, 38606],
        "$25_prizes" : [166400, np.nan, np.nan, np.nan, np.nan, np.nan, 70308, np.nan, 111268, 28303, 73599, 63181, 82064, np.nan, 80514, 18877],
        "$30_prizes" : [77962, 407563, 492836, 203237, np.nan, 74955, 34064, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 332596, 39276, 9500],
        "$40_prizes" : [np.nan, 406449, np.nan, 200798, 332866, 40728, 34615, 188428, 219904, 53010, 162832, 123532, 160951, np.nan, 38641, 8028],
        "$50_prizes" : [118562, 406362, 391568, 200606, 197385, 13387, 34538, 62967, 105574, 26638, 72474, 61280, 80609, 359564, 38913, 8191],
        "$70_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 3918],
        "$75_prizes" : [15722, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,], 
        "$100_prizes" : [39086, 237074, 105091, 93424, 130675, 13468, 43760, 80187, 126588, 31094, 108014, 77124, 95677, 165033, 32115, 4677],
        "$150_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, 2689, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,],
        "$200_prizes" : [6642, 19317, 17203, 7424, 4902, 1574, 4016, 8241, 18655, 4505, 15138, 10126, 13986, 5188, 6802, 1153],
        "$250_prizes" : [781, np.nan, np.nan, np.nan, np.nan, 797, 1031, np.nan, 2999, np.nan, 1781, np.nan, 2233, np.nan, np.nan, np.nan,],
        "$300_prizes" : [np.nan, np.nan, 10040, np.nan, np.nan, 662, np.nan, np.nan, np.nan,np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,],
        "$350_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 104],
        "$400_prizes" : [np.nan, 7664, 8579, 3755, np.nan, 787, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 1634, np.nan],
        "$500_prizes" : [3275,11822, 8319, 5828, 4450, 820, 1293, 3891, 7570, 2074, 864, 5015, 6299, 4559, 282, 332],
        "$1000_prizes" : [632, 706, 1323, 1825, 1669, 428, 334, 629, 896, 258, 438, 521, 653, 862, 369, 84],
        "$3000_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 49, np.nan],
        "$5000_prizes" : [np.nan, 21, 52, 38, np.nan, np.nan, 28, np.nan, np.nan, np.nan, np.nan, 8, np.nan, np.nan, np.nan, 15],
        "$7000_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 27, 4],
        "$10000_prizes" : [2, np.nan, np.nan, np.nan, 47, 6, np.nan, 11, 20, 2, np.nan, np.nan, 15, np.nan, np.nan, np.nan],
        "$17777_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 3],
        "$20000_prizes" : [np.nan, 16, 15, 8, np.nan, np.nan, 9, np.nan, 8, 2, 5, np.nan, 6, 52, 13, np.nan],
        "$25000_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 5, np.nan, np.nan, np.nan, np.nan],
        "$50000_prizes" : [np.nan, np.nan, np.nan, np.nan, 11, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
        "$77777_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0],
        "$100000_prizes" : [2, 3, 3, 1, np.nan, 2, np.nan, 1, 3, 0, 1, 2, 3, np.nan, 5, np.nan],
        "$600000_prizes" : [np.nan, 19, np.nan, np.nan, np.nan, np.nan, 1, 2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
        "$1000000_prizes" : [1, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2, np.nan],
        "$1200000_prizes" : [np.nan, np.nan, np.nan, np.nan, 4, np.nan, np.nan, np.nan, 2, 1, 2, 2, 1, np.nan, np.nan, np.nan],
        "$1777777_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 1],
        "$3000000_prizes" : [np.nan, np.nan, 3, 2, np.nan, 0, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
        "$7200000_prizes" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 1, np.nan, np.nan]
       
       }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                          card_name  card_price  weeks_in_market  $20_prizes  \
# 0            DIAMOND CROSSWORD 10X          25               86         NaN
# 1      1,000,000 CASH CELEBRATION!          30               12         NaN
# 2                  MILLION $ MATCH          30               34         NaN
# 3                $5 MILLION RICHES          30               52         NaN
# 4     PLATINUM DIAMOND SPECTACULAR          30               73         NaN
# 5                ULTIMATE MILLIONS          30              158         NaN
# 6      $1,000,000 MERRY MULTIPLIER          20                8    140798.0
# 7   MILLION DOLLAR MEGA MULTIPLIER          20               21    253307.0
# 8          $2,000,000 EXTREME CASH          20               30    445404.0
# 9              $2,000,000 BANKROLL          20               39    110747.0
# 10                         WIN BIG          20               43    258604.0
# ...

# %%
df.to_csv ('lottery_tickets.csv', index = True, header=True)

# %% [markdown]
# ## That Looks super cool, and it's way easier to compare prizes than on the Lottery website

# %% [markdown]
# ### Let's print out some graphs to help see each card and its available prizes

# %%
dft = df.set_index('card_name').T

# %%
# convert the dataframe to long format
dfm = df.melt(id_vars='card_name')

# %%
axes = dft.plot(kind='bar', rot=70, subplots=True, sharey=True,figsize=(40, 100))
for ax in axes.flat: 
    ax.tick_params(labelbottom=True)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=30)

# %%
# Uncomment for an alternate plot

# p = sns.catplot(kind='bar', data=dfm, x='variable', y='value', row='card_name', height=3, aspect=7)

# %% [markdown]
# ### We need a look at some of the numbers here

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   card_name        16 non-null     object
#  1   card_price       16 non-null     int64
#  2   weeks_in_market  16 non-null     int64
#  3   $20_prizes       10 non-null     float64
#  4   $25_prizes       9 non-null      float64
#  5   $30_prizes       9 non-null      float64
#  6   $40_prizes       13 non-null     float64
#  7   $50_prizes       16 non-null     int64
#  8   $70_prizes       1 non-null      float64
#  9   $75_prizes       1 non-null      float64
#  10  $100_prizes      16 non-null     int64
#  11  $150_prizes      1 non-null      float64
#  12  $200_prizes      16 non-null     int64
#  13  $250_prizes      6 non-null      float64
#  14  $300_prizes      2 non-null      float64
#  15  $350_prizes      1 non-null      float64
# ...

# %%
df.describe()
# Out:
#        card_price  weeks_in_market     $20_prizes     $25_prizes  \
# count   16.000000        16.000000      10.000000       9.000000
# mean    23.437500        64.250000  282766.000000   77168.222222
# std      4.732424        45.279134  227507.167031   43590.980706
# min     20.000000         8.000000   38606.000000   18877.000000
# 25%     20.000000        33.000000  145638.250000   63181.000000
# 50%     20.000000        50.000000  252355.000000   73599.000000
# 75%     30.000000        87.500000  311166.250000   82064.000000
# max     30.000000       158.000000  839945.000000  166400.000000
#
#           $30_prizes     $40_prizes     $50_prizes  $70_prizes  $75_prizes  \
# count       9.000000      13.000000      16.000000         1.0         1.0
# mean   185776.555556  151598.615385  136163.625000      3918.0     15722.0
# std    181931.813341  121215.958094  136292.112153         NaN         NaN
# min      9500.000000    8028.000000    8191.000000      3918.0     15722.0
# ...

# %% [markdown]
# print out the card names

# %%
card_order = df['card_name'].values
card_order
# Out:
# array(['DIAMOND CROSSWORD 10X', '1,000,000 CASH CELEBRATION!',
#        'MILLION $ MATCH', '$5 MILLION RICHES',
#        'PLATINUM DIAMOND SPECTACULAR', 'ULTIMATE MILLIONS',
#        '$1,000,000 MERRY MULTIPLIER', 'MILLION DOLLAR MEGA MULTIPLIER',
#        '$2,000,000 EXTREME CASH', '$2,000,000 BANKROLL', 'WIN BIG',
#        '100X THE CASH', '$2,000,000 JACKPOT', '20 YEARS OF CASH',
#        'PAY ME!', 'LUCKY 7 DELUXE'], dtype=object)

# %% [markdown]
# # We've got to turn each row into its own Pandas Series.<br>We'll start with the first row, which is DIAMOND CROSSWORD 10X

# %% [markdown]
# ## DIAMOND CROSSWORD 10X

# %%
diamond_crossword_10x = df.iloc[0]
diamond_crossword_10x = diamond_crossword_10x.dropna()
diamond_crossword_10x.to_frame()
diamond_crossword_10x
# Out:
# card_name          DIAMOND CROSSWORD 10X
# card_price                            25
# weeks_in_market                       86
# $25_prizes                      166400.0
# $30_prizes                       77962.0
# $50_prizes                        118562
# $75_prizes                       15722.0
# $100_prizes                        39086
# $200_prizes                         6642
# $250_prizes                        781.0
# $500_prizes                         3275
# $1000_prizes                         632
# $10000_prizes                        2.0
# $100000_prizes                       2.0
# $1000000_prizes                      1.0
# Name: 0, dtype: object

# %% [markdown]
# ## 1,000,000 CASH CELEBRATION!

# %%
million_dollar_cash_celbration =  df.iloc[1]
million_dollar_cash_celbration = million_dollar_cash_celbration.dropna()
million_dollar_cash_celbration.to_frame()
million_dollar_cash_celbration
# Out:
# card_name          1,000,000 CASH CELEBRATION!
# card_price                                  30
# weeks_in_market                             12
# $30_prizes                            407563.0
# $40_prizes                            406449.0
# $50_prizes                              406362
# $100_prizes                             237074
# $200_prizes                              19317
# $400_prizes                             7664.0
# $500_prizes                              11822
# $1000_prizes                               706
# $5000_prizes                              21.0
# $20000_prizes                             16.0
# $100000_prizes                             3.0
# $600000_prizes                            19.0
# Name: 1, dtype: object

# %% [markdown]
# ## MILLION (DOLLAR SIGN) MATCH

# %%
million_dollarsign_match =  df.iloc[2]
million_dollarsign_match = million_dollarsign_match.dropna()
million_dollarsign_match.to_frame()
million_dollarsign_match
# Out:
# card_name          MILLION $ MATCH
# card_price                      30
# weeks_in_market                 34
# $30_prizes                492836.0
# $50_prizes                  391568
# $100_prizes                 105091
# $200_prizes                  17203
# $300_prizes                10040.0
# $400_prizes                 8579.0
# $500_prizes                   8319
# $1000_prizes                  1323
# $5000_prizes                  52.0
# $20000_prizes                 15.0
# $100000_prizes                 3.0
# $3000000_prizes                3.0
# Name: 2, dtype: object

# %% [markdown]
# ## DOLLAR SIGN 5 MILLION RICHES

# %%
dollarsign_five_million_riches =  df.iloc[3]
dollarsign_five_million_riches = dollarsign_five_million_riches.dropna()
dollarsign_five_million_riches.to_frame()
dollarsign_five_million_riches
# Out:
# card_name          $5 MILLION RICHES
# card_price                        30
# weeks_in_market                   52
# $30_prizes                  203237.0
# $40_prizes                  200798.0
# $50_prizes                    200606
# $100_prizes                    93424
# $200_prizes                     7424
# $400_prizes                   3755.0
# $500_prizes                     5828
# $1000_prizes                    1825
# $5000_prizes                    38.0
# $20000_prizes                    8.0
# $100000_prizes                   1.0
# $3000000_prizes                  2.0
# Name: 3, dtype: object

# %% [markdown]
# ## PLATINUM DIAMOND SPECTACULAR

# %%
platinum_diamond_spectacular =  df.iloc[4]
platinum_diamond_spectacular = platinum_diamond_spectacular.dropna()
platinum_diamond_spectacular.to_frame()
platinum_diamond_spectacular
# Out:
# card_name          PLATINUM DIAMOND SPECTACULAR
# card_price                                   30
# weeks_in_market                              73
# $40_prizes                             332866.0
# $50_prizes                               197385
# $100_prizes                              130675
# $200_prizes                                4902
# $500_prizes                                4450
# $1000_prizes                               1669
# $10000_prizes                              47.0
# $50000_prizes                              11.0
# $1200000_prizes                             4.0
# Name: 4, dtype: object

# %% [markdown]
# ## ULTIMATE MILLIONS

# %%
ultimate_millions =  df.iloc[5]
ultimate_millions = ultimate_millions.dropna()
ultimate_millions.to_frame()
ultimate_millions
# Out:
# card_name          ULTIMATE MILLIONS
# card_price                        30
# weeks_in_market                  158
# $30_prizes                   74955.0
# $40_prizes                   40728.0
# $50_prizes                     13387
# $100_prizes                    13468
# $150_prizes                   2689.0
# $200_prizes                     1574
# $250_prizes                    797.0
# $300_prizes                    662.0
# $400_prizes                    787.0
# $500_prizes                      820
# $1000_prizes                     428
# $10000_prizes                    6.0
# $100000_prizes                   2.0
# $3000000_prizes                  0.0
# Name: 5, dtype: object

# %% [markdown]
# ## DOLLAR SIGN 1,000,000 MERRY MULTIPLIER

# %%
dollarsign_onemillion_merry_multiplier =  df.iloc[6]
dollarsign_onemillion_merry_multiplier = dollarsign_onemillion_merry_multiplier.dropna()
dollarsign_onemillion_merry_multiplier.to_frame()
dollarsign_onemillion_merry_multiplier
# Out:
# card_name          $1,000,000 MERRY MULTIPLIER
# card_price                                  20
# weeks_in_market                              8
# $20_prizes                            140798.0
# $25_prizes                             70308.0
# $30_prizes                             34064.0
# $40_prizes                             34615.0
# $50_prizes                               34538
# $100_prizes                              43760
# $200_prizes                               4016
# $250_prizes                             1031.0
# $500_prizes                               1293
# $1000_prizes                               334
# $5000_prizes                              28.0
# $20000_prizes                              9.0
# $600000_prizes                             1.0
# Name: 6, dtype: object

# %% [markdown]
# ## MILLION DOLLAR MEGA MULTIPIER

# %%
million_dollar_mega_multipier =  df.iloc[7]
million_dollar_mega_multipier = million_dollar_mega_multipier.dropna()
million_dollar_mega_multipier.to_frame()
million_dollar_mega_multipier
# Out:
# card_name          MILLION DOLLAR MEGA MULTIPLIER
# card_price                                     20
# weeks_in_market                                21
# $20_prizes                               253307.0
# $40_prizes                               188428.0
# $50_prizes                                  62967
# $100_prizes                                 80187
# $200_prizes                                  8241
# $500_prizes                                  3891
# $1000_prizes                                  629
# $10000_prizes                                11.0
# $100000_prizes                                1.0
# $600000_prizes                                2.0
# Name: 7, dtype: object

# %% [markdown]
# ## DOLLAR SIGN 2,000,000 EXTREME CASH

# %%
dollarsign_twomillion_extreme_cash =  df.iloc[8]
dollarsign_twomillion_extreme_cash = dollarsign_twomillion_extreme_cash.dropna()
dollarsign_twomillion_extreme_cash.to_frame()
dollarsign_twomillion_extreme_cash
# Out:
# card_name          $2,000,000 EXTREME CASH
# card_price                              20
# weeks_in_market                         30
# $20_prizes                        445404.0
# $25_prizes                        111268.0
# $40_prizes                        219904.0
# $50_prizes                          105574
# $100_prizes                         126588
# $200_prizes                          18655
# $250_prizes                         2999.0
# $500_prizes                           7570
# $1000_prizes                           896
# $10000_prizes                         20.0
# $20000_prizes                          8.0
# $100000_prizes                         3.0
# $1200000_prizes                        2.0
# Name: 8, dtype: object

# %% [markdown]
# ## DOLLAR SIGN 2,000,000 BANK ROLL

# %%
dollarsign_twomillion_bank_roll =  df.iloc[9]
dollarsign_twomillion_bank_roll = dollarsign_twomillion_bank_roll.dropna()
dollarsign_twomillion_bank_roll.to_frame()
dollarsign_twomillion_bank_roll
# Out:
# card_name          $2,000,000 BANKROLL
# card_price                          20
# weeks_in_market                     39
# $20_prizes                    110747.0
# $25_prizes                     28303.0
# $40_prizes                     53010.0
# $50_prizes                       26638
# $100_prizes                      31094
# $200_prizes                       4505
# $500_prizes                       2074
# $1000_prizes                       258
# $10000_prizes                      2.0
# $20000_prizes                      2.0
# $100000_prizes                     0.0
# $1200000_prizes                    1.0
# Name: 9, dtype: object

# %% [markdown]
# ## WIN BIG

# %%
win_big =  df.iloc[10]
win_big = win_big.dropna()
win_big.to_frame()
win_big
# Out:
# card_name           WIN BIG
# card_price               20
# weeks_in_market          43
# $20_prizes         258604.0
# $25_prizes          73599.0
# $40_prizes         162832.0
# $50_prizes            72474
# $100_prizes          108014
# $200_prizes           15138
# $250_prizes          1781.0
# $500_prizes             864
# $1000_prizes            438
# $20000_prizes           5.0
# $100000_prizes          1.0
# $1200000_prizes         2.0
# Name: 10, dtype: object

# %% [markdown]
# ## 100X THE CASH

# %%
onehundred_x_the_cash =  df.iloc[11]
onehundred_x_the_cash = onehundred_x_the_cash.dropna()
onehundred_x_the_cash.to_frame()
onehundred_x_the_cash
# Out:
# card_name          100X THE CASH
# card_price                    20
# weeks_in_market               48
# $20_prizes              251403.0
# $25_prizes               63181.0
# $40_prizes              123532.0
# $50_prizes                 61280
# $100_prizes                77124
# $200_prizes                10126
# $500_prizes                 5015
# $1000_prizes                 521
# $5000_prizes                 8.0
# $25000_prizes                5.0
# $100000_prizes               2.0
# $1200000_prizes              2.0
# Name: 11, dtype: object

# %% [markdown]
# ## DOLLAR SIGN 2,000,000 JACKPOT

# %%
dollarsign_twomillion_jackpot =  df.iloc[12]
dollarsign_twomillion_jackpot = dollarsign_twomillion_jackpot.dropna()
dollarsign_twomillion_jackpot.to_frame()
dollarsign_twomillion_jackpot
# Out:
# card_name          $2,000,000 JACKPOT
# card_price                         20
# weeks_in_market                    69
# $20_prizes                   328687.0
# $25_prizes                    82064.0
# $40_prizes                   160951.0
# $50_prizes                      80609
# $100_prizes                     95677
# $200_prizes                     13986
# $250_prizes                    2233.0
# $500_prizes                      6299
# $1000_prizes                      653
# $10000_prizes                    15.0
# $20000_prizes                     6.0
# $100000_prizes                    3.0
# $1200000_prizes                   1.0
# Name: 12, dtype: object

# %% [markdown]
# ## 20 YEARS OF CASH

# %%
twenty_years_of_cash =  df.iloc[13]
twenty_years_of_cash = twenty_years_of_cash.dropna()
twenty_years_of_cash.to_frame()
twenty_years_of_cash
# Out:
# card_name          20 YEARS OF CASH
# card_price                       20
# weeks_in_market                  92
# $20_prizes                 839945.0
# $30_prizes                 332596.0
# $50_prizes                   359564
# $100_prizes                  165033
# $200_prizes                    5188
# $500_prizes                    4559
# $1000_prizes                    862
# $20000_prizes                  52.0
# $7200000_prizes                 1.0
# Name: 13, dtype: object

# %% [markdown]
# ## Pay ME!

# %%
pay_me_exclamationmark =  df.iloc[14]
pay_me_exclamationmark = pay_me_exclamationmark.dropna()
pay_me_exclamationmark.to_frame()
pay_me_exclamationmark
# Out:
# card_name           PAY ME!
# card_price               20
# weeks_in_market         121
# $20_prizes         160159.0
# $25_prizes          80514.0
# $30_prizes          39276.0
# $40_prizes          38641.0
# $50_prizes            38913
# $100_prizes           32115
# $200_prizes            6802
# $400_prizes          1634.0
# $500_prizes             282
# $1000_prizes            369
# $3000_prizes           49.0
# $7000_prizes           27.0
# $20000_prizes          13.0
# $100000_prizes          5.0
# $1000000_prizes         2.0
# Name: 14, dtype: object

# %% [markdown]
# ## LUCKY 7 DELUXE

# %%
lucky_thenumberseven_deluxe =  df.iloc[15]
lucky_thenumberseven_deluxe = lucky_thenumberseven_deluxe.dropna()
lucky_thenumberseven_deluxe.to_frame()
lucky_thenumberseven_deluxe
new = lucky_thenumberseven_deluxe.drop(['weeks_in_market']) # experimenting to see how to drop certain rows
new
# Out:
# card_name          LUCKY 7 DELUXE
# card_price                     20
# $20_prizes                38606.0
# $25_prizes                18877.0
# $30_prizes                 9500.0
# $40_prizes                 8028.0
# $50_prizes                   8191
# $70_prizes                 3918.0
# $100_prizes                  4677
# $200_prizes                  1153
# $350_prizes                 104.0
# $500_prizes                   332
# $1000_prizes                   84
# $5000_prizes                 15.0
# $7000_prizes                  4.0
# $17777_prizes                 3.0
# $77777_prizes                 0.0
# $1777777_prizes               1.0
# Name: 15, dtype: object

# %%
list_of_cards = [diamond_crossword_10x, million_dollar_cash_celbration, million_dollarsign_match,
                dollarsign_five_million_riches, platinum_diamond_spectacular, ultimate_millions, 
                dollarsign_onemillion_merry_multiplier, million_dollar_mega_multipier,
                dollarsign_twomillion_extreme_cash, dollarsign_twomillion_bank_roll, win_big,
                onehundred_x_the_cash, dollarsign_twomillion_jackpot, twenty_years_of_cash, 
                pay_me_exclamationmark, lucky_thenumberseven_deluxe]
con = pd.concat(list_of_cards, axis=0)

# %% [markdown]
# # Here's a print out of all the 20–30 Dollar scratch-offs and their available prizes as of 11-21-2021

# %%
pd.set_option('display.max_rows', None)
con
# Out:
# card_name                   DIAMOND CROSSWORD 10X
# card_price                                     25
# weeks_in_market                                86
# $25_prizes                               166400.0
# $30_prizes                                77962.0
# $50_prizes                                 118562
# $75_prizes                                15722.0
# $100_prizes                                 39086
# $200_prizes                                  6642
# $250_prizes                                 781.0
# $500_prizes                                  3275
# $1000_prizes                                  632
# $10000_prizes                                 2.0
# $100000_prizes                                2.0
# $1000000_prizes                               1.0
# card_name             1,000,000 CASH CELEBRATION!
# card_price                                     30
# weeks_in_market                                12
# $30_prizes                               407563.0
# ...

# %% [markdown]
# # Isolating Prize amounts and Cards

# %%
card_order = list(card_order)
card_order
# Out:
# ['DIAMOND CROSSWORD 10X',
#  '1,000,000 CASH CELEBRATION!',
#  'MILLION $ MATCH',
#  '$5 MILLION RICHES',
#  'PLATINUM DIAMOND SPECTACULAR',
#  'ULTIMATE MILLIONS',
#  '$1,000,000 MERRY MULTIPLIER',
#  'MILLION DOLLAR MEGA MULTIPLIER',
#  '$2,000,000 EXTREME CASH',
#  '$2,000,000 BANKROLL',
#  'WIN BIG',
#  '100X THE CASH',
#  '$2,000,000 JACKPOT',
#  '20 YEARS OF CASH',
#  'PAY ME!',
#  'LUCKY 7 DELUXE']

# %% [markdown]
# # Cards with 1,000 Dollars

# %%
# enumerate to get card names and index numbers

thousand = con.get(key = '$1000_prizes')
thousand = list(thousand)

thousand_list = []

for _, how_many in enumerate(thousand):
    thousand_list.append(how_many)
thousand_list = list(thousand_list)

# zipping enumerate value results with list from above (card_order)
a_zip = zip(card_order, thousand_list)

thousand_cards = list(a_zip)
thousand_cards
# Out:
# [('DIAMOND CROSSWORD 10X', 632),
#  ('1,000,000 CASH CELEBRATION!', 706),
#  ('MILLION $ MATCH', 1323),
#  ('$5 MILLION RICHES', 1825),
#  ('PLATINUM DIAMOND SPECTACULAR', 1669),
#  ('ULTIMATE MILLIONS', 428),
#  ('$1,000,000 MERRY MULTIPLIER', 334),
#  ('MILLION DOLLAR MEGA MULTIPLIER', 629),
#  ('$2,000,000 EXTREME CASH', 896),
#  ('$2,000,000 BANKROLL', 258),
#  ('WIN BIG', 438),
#  ('100X THE CASH', 521),
#  ('$2,000,000 JACKPOT', 653),
#  ('20 YEARS OF CASH', 862),
#  ('PAY ME!', 369),
#  ('LUCKY 7 DELUXE', 84)]

# %% [markdown]
# # Cards with 100 Dollars

# %%
# enumerate to get card names and index numbers

hundred = con.get(key = '$100_prizes')
hundred  = list(hundred )

hundred_list = []

for _, how_many in enumerate(hundred ):
    hundred_list.append(how_many)
hundred_list = list(hundred_list)

# zipping enumerate value results with list from above (card_order)
a_zip = zip(card_order, hundred_list)

hundred_cards = list(a_zip)
hundred_cards
# Out:
# [('DIAMOND CROSSWORD 10X', 39086),
#  ('1,000,000 CASH CELEBRATION!', 237074),
#  ('MILLION $ MATCH', 105091),
#  ('$5 MILLION RICHES', 93424),
#  ('PLATINUM DIAMOND SPECTACULAR', 130675),
#  ('ULTIMATE MILLIONS', 13468),
#  ('$1,000,000 MERRY MULTIPLIER', 43760),
#  ('MILLION DOLLAR MEGA MULTIPLIER', 80187),
#  ('$2,000,000 EXTREME CASH', 126588),
#  ('$2,000,000 BANKROLL', 31094),
#  ('WIN BIG', 108014),
#  ('100X THE CASH', 77124),
#  ('$2,000,000 JACKPOT', 95677),
#  ('20 YEARS OF CASH', 165033),
#  ('PAY ME!', 32115),
#  ('LUCKY 7 DELUXE', 4677)]

# %% [markdown]
# # Cards with 100,000 Dollars

# %%
# enumerate to get card names and index numbers

hundred_thousand = con.get(key = '$100000_prizes')
hundred_thousand  = list(hundred_thousand)

hundred_thousand_list = []

for _, how_many in enumerate(hundred_thousand):
    hundred_thousand_list.append(how_many)
hundred_thousand_list = list(hundred_thousand_list)

# zipping enumerate value results with list from above (card_order)
a_zip = zip(card_order, hundred_thousand_list)

hundred_thousand_cards = list(a_zip)
hundred_thousand_cards
# Out:
# [('DIAMOND CROSSWORD 10X', 2.0),
#  ('1,000,000 CASH CELEBRATION!', 3.0),
#  ('MILLION $ MATCH', 3.0),
#  ('$5 MILLION RICHES', 1.0),
#  ('PLATINUM DIAMOND SPECTACULAR', 2.0),
#  ('ULTIMATE MILLIONS', 1.0),
#  ('$1,000,000 MERRY MULTIPLIER', 3.0),
#  ('MILLION DOLLAR MEGA MULTIPLIER', 0.0),
#  ('$2,000,000 EXTREME CASH', 1.0),
#  ('$2,000,000 BANKROLL', 2.0),
#  ('WIN BIG', 3.0),
#  ('100X THE CASH', 5.0)]

# %% [markdown]
# # Cards with 50 Dollars

# %%
# enumerate to get card names and index numbers

fifty = con.get(key = '$50_prizes')
fifty  = list(fifty)

fifty_list = []

for _, how_many in enumerate(fifty):
    fifty_list.append(how_many)
fifty_list = list(fifty_list)

# zipping enumerate value results with list from above (card_order)
a_zip = zip(card_order, fifty_list)

hundred_thousand_cards = list(a_zip)
hundred_thousand_cards
# Out:
# [('DIAMOND CROSSWORD 10X', 118562),
#  ('1,000,000 CASH CELEBRATION!', 406362),
#  ('MILLION $ MATCH', 391568),
#  ('$5 MILLION RICHES', 200606),
#  ('PLATINUM DIAMOND SPECTACULAR', 197385),
#  ('ULTIMATE MILLIONS', 13387),
#  ('$1,000,000 MERRY MULTIPLIER', 34538),
#  ('MILLION DOLLAR MEGA MULTIPLIER', 62967),
#  ('$2,000,000 EXTREME CASH', 105574),
#  ('$2,000,000 BANKROLL', 26638),
#  ('WIN BIG', 72474),
#  ('100X THE CASH', 61280),
#  ('$2,000,000 JACKPOT', 80609),
#  ('20 YEARS OF CASH', 359564),
#  ('PAY ME!', 38913),
#  ('LUCKY 7 DELUXE', 8191)]

# %% [markdown]
# # Round 5

# %% [markdown]
# ## 1 - PLATINUM DIAMOND SPECTACULAR (30 Dollars)<br>3 - 100X THE CASH (20 Dollars)<br>4 - Dollar Sign Two Million JACKPOT (20 Dollars)

# %%
pds_winings = np.array([50])
hundred_x_the_cash_winnings = np.array([20 + 0 + 0 + 0])
ds_twomillion_jackpot_winnings = np.array([20 + 0 + 0])
round_five_winnings = pds_winings + hundred_x_the_cash_winnings + ds_twomillion_jackpot_winnings

# %%
attempt_5 = "round five"

start_with_5 = ended_with_4

spent_5 = ended_with_4

left_with_5 = start_with_5 - spent_5

won_5 = round_five_winnings

status_2 = won_5 - spent_5

lost_5 = spent_5 - won_5

ended_with_5 = won_5 + left_with_5

#reinvest_1 = start_with_1 - abs(status_1)

# %%
print(f"Starting with ${start_with_5}")
print()
print(f"Spent ${spent_5} ")
print()
print(f"Left with ${start_with_5 - spent_5}")
print()
print(f"Won ${won_5}")
print()
print(f"Lost ${lost_5}")
print()
print(f"Result to reinvest ${ended_with_5}")
# Out:
# Starting with $170
#
# Spent $170
#
# Left with $0
#
# Won $[90]
#
# Lost $[80]
#
# Result to reinvest $[90]

# %% [markdown]
# ## This isn't going well, monetrailly. As an Data Science project it's going great

# %% [markdown]
# # Round 6

# %%
hundred_x_the_cash_winnings_6 = np.array([20 + 0 + 0])
ds_twomillion_jackpot_winnings_6 = np.array([0])
ds_onemillion_cash_extreme = np.array([0]) # I messed up and had to buy a $10 card
round_six_winnings = hundred_x_the_cash_winnings_6 + ds_twomillion_jackpot_winnings_6 + ds_onemillion_cash_extreme

# %%
attempt_6 = "round six"

start_with_6 = ended_with_5

spent_6 = ended_with_5

left_with_6 = start_with_6 - spent_6

won_6 = round_six_winnings

status_6 = won_6 - spent_6

lost_6 = spent_6 - won_6

ended_with_6 = won_6 + left_with_6

#reinvest_1 = start_with_1 - abs(status_1)

# %%
print(f"Starting with ${start_with_6}")
print()
print(f"Spent ${spent_6} ")
print()
print(f"Left with ${start_with_6 - spent_6}")
print()
print(f"Won ${won_6}")
print()
print(f"Lost ${lost_6}")
print()
print(f"Result to reinvest ${ended_with_6}")
# Out:
# Starting with $[90]
#
# Spent $[90]
#
# Left with $[0]
#
# Won $[20]
#
# Lost $[70]
#
# Result to reinvest $[20]

# %% [markdown]
# ## Oof, that stings. Left with only 20 Dollars out of 300

# %% [markdown]
# ### It only takes one, they say

# %% [markdown]
# ## It didn't only take one

# %% [markdown]
# # Round 7

# %%
attempt_7 = "Round 7"

start_with_7 = ended_with_6

spent_7 = start_with_7

left_with_7 = start_with_7 - spent_7

won_7 = 25

status_7 = won_7 - spent_7

lost_7 = spent_7 - won_7

ended_with_7 = won_7 + left_with_7

# %%
print(f"Starting with ${start_with_7}")
print()
print(f"Spent ${spent_7} ")
print()
print(f"Left with ${start_with_7 - spent_7}")
print()
print(f"Won ${won_7}")
print()
print(f"Lost ${lost_7}")
print()
print(f"Result to reinvest ${ended_with_7}")
# Out:
# Starting with $[20]
#
# Spent $[20]
#
# Left with $[0]
#
# Won $25
#
# Lost $[-5]
#
# Result to reinvest $[25]

# %% [markdown]
# # Round 8

# %%
attempt_8 = "Round 8"

start_with_8 = ended_with_7

spent_8 = start_with_8

left_with_8 = start_with_8 - spent_8

won_8 = 40

status_8 = won_8 - spent_8

lost_8 = spent_8 - won_8

ended_with_8 = won_8 + left_with_8

# %%
print(f"Starting with ${start_with_8}")
print()
print(f"Spent ${spent_8} ")
print()
print(f"Left with ${start_with_8 - spent_8}")
print()
print(f"Won ${won_8}")
print()
print(f"Lost ${lost_8}")
print()
print(f"Result to reinvest ${ended_with_8}")
# Out:
# Starting with $[25]
#
# Spent $[25]
#
# Left with $[0]
#
# Won $40
#
# Lost $[-15]
#
# Result to reinvest $[40]

# %% [markdown]
# # Round 9

# %%
attempt_9 = "Round 9"

start_with_9 = ended_with_8

spent_9 = start_with_9

left_with_9 = start_with_9 - spent_9

won_9 = 0

status_9 = won_9 - spent_9

lost_9 = spent_9 - won_9

ended_with_9 = won_9 + left_with_9

# %%
print(f"Starting with ${start_with_9}")
print()
print(f"Spent ${spent_9} ")
print()
print(f"Left with ${start_with_9 - spent_9}")
print()
print(f"Won ${won_9}")
print()
print(f"Lost ${lost_9}")
print()
print(f"Result to reinvest ${ended_with_9}")
# Out:
# Starting with $[40]
#
# Spent $[40]
#
# Left with $[0]
#
# Won $0
#
# Lost $[40]
#
# Result to reinvest $[0]

# %% [markdown]
# #### So there you have it. We started out with 300 Dollars and now have 0 Dollars to reinvest. It is tempting to commit more money to the experiment. After all, that is one of the conditions that Joan Ginther, who has a PhD in Math from Stanford, satisfied in her conquest to win 20 Million Dollars from scratch-offs. She bought a lot of cards. It is my belief that, more purchased cards with the utilization of the above card data, would increase the odds of winning to an almost mathematical certainty. I know this exercise may seem like a failure. We did lose 300 Dollars. But, the approach was solid, and deserves further development in the future. And besides, it was not a total fruitless endeavor. Look at the beatiful dataframe that was created. I've posted it on Kaggle and the CSV to the GitHub repo, so it is out there in the world for anyone who might need a dataframe to work with. The scratch off cards, themselves, also became less of a mystery to me. With a little luck, who knows what will happen down the line. We may have just scratched the surface.
